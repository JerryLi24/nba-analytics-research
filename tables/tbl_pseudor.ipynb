# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
from numpy.linalg import LinAlgError
pd.set_option('display.max_columns', None)

# %%
import pandas as pd
import statsmodels.api as sm

# The factors we want to test
factors = ['diff_orb', 'diff_tov', 'diff_3p%', 'diff_2p%', 'diff_ft%', 'diff_fta', 'diff_3pa']

# Read in the cleansed data
df = pd.read_csv('/Users/moneysniper/Documents/NBA_analysis_project/gamelogs/nba_games_cleansed.csv')

# Filter down to home games and drop rows missing the columns of interest
cols_to_select = [
    'home', 'season', 'won', 'diff_pts', 'diff_orb', 'diff_tov', 
    'diff_3p%', 'diff_2p%', 'diff_ft%', 'diff_fta', 'diff_3pa'
]
df = (
    df[df["home"] == 1]                # Keep only home games
    .reset_index(drop=True)[cols_to_select]
    .dropna(subset=cols_to_select)     # Drop rows with NaNs in the relevant columns
)

# Group the cleansed data by season
grouped = df.groupby('season')

pseudo_r_squared = {}

for season_name, group in grouped:
    # Make sure the group has no missing data for the factors and 'won'
    group = group.dropna(subset=factors + ['won'])
    
    pseudo_r_squared[season_name] = {}
    
    # Exclude each factor one at a time
    for excluded_factor in factors:
        # Create a list of factors that excludes the current factor
        factors_subset = [f for f in factors if f != excluded_factor]
        
        X = group[factors_subset]
        y = group['won']
        
        # Add a constant term for the logistic model
        X = sm.add_constant(X)
        
        # Fit the logistic regression
        model = sm.Logit(y, X)
        result = model.fit(disp=0)  # disp=0 prevents printing iteration info, but you can remove it if you want
        
        # Print the model summary (optional)
        print(result.summary(title=f'Season {season_name} - Excluding {excluded_factor}'))
        
        # Store the pseudo R-squared for this model
        pseudo_r_squared[season_name][excluded_factor] = result.prsquared

# Convert the dictionary of results to a DataFrame
pseudo_r_squared_df = pd.DataFrame(pseudo_r_squared)
pseudo_r_squared_df.to_csv('pseudo_r_squared_cleansed.csv', index=True)

# Also display or inspect the DataFrame in Python
print(pseudo_r_squared_df)
# Out:
#                        Season 2016 - Excluding diff_orb
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1316
# Model:                          Logit   Df Residuals:                     1309
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6160
# Time:                        15:11:32   Log-Likelihood:                -341.22
# converged:                       True   LL-Null:                       -888.67
# Covariance Type:            nonrobust   LLR p-value:                2.625e-233
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2335      0.099      2.355      0.018       0.039       0.428
# diff_tov      -0.2630      0.023    -11.196      0.000      -0.309      -0.217
# diff_3p%       0.1855      0.012     15.861      0.000       0.163       0.208
# diff_2p%       0.2955      0.019     15.698      0.000       0.259       0.332
# diff_ft%       0.0625      0.008      8.148      0.000       0.048       0.078
# diff_fta       0.1366      0.013     10.731      0.000       0.112       0.162
# diff_3pa       0.0334      0.011      3.074      0.002       0.012       0.055
# ==============================================================================
#                        Season 2016 - Excluding diff_tov
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1316
# Model:                          Logit   Df Residuals:                     1309
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6314
# Time:                        15:11:32   Log-Likelihood:                -327.61
# converged:                       True   LL-Null:                       -888.67
# Covariance Type:            nonrobust   LLR p-value:                3.399e-239
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1702      0.101      1.691      0.091      -0.027       0.367
# diff_orb       0.3077      0.026     11.643      0.000       0.256       0.359
# diff_3p%       0.2192      0.014     15.741      0.000       0.192       0.247
# diff_2p%       0.3647      0.023     16.100      0.000       0.320       0.409
# diff_ft%       0.0688      0.008      8.820      0.000       0.054       0.084
# diff_fta       0.1439      0.013     10.843      0.000       0.118       0.170
# diff_3pa       0.0184      0.011      1.658      0.097      -0.003       0.040
# ==============================================================================
#                        Season 2016 - Excluding diff_3p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1316
# Model:                          Logit   Df Residuals:                     1309
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.3127
# Time:                        15:11:32   Log-Likelihood:                -610.75
# converged:                       True   LL-Null:                       -888.67
# Covariance Type:            nonrobust   LLR p-value:                7.753e-117
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2093      0.071      2.945      0.003       0.070       0.349
# diff_orb       0.0867      0.014      6.126      0.000       0.059       0.114
# diff_tov      -0.1395      0.015     -9.141      0.000      -0.169      -0.110
# diff_2p%       0.1846      0.011     16.130      0.000       0.162       0.207
# diff_ft%       0.0396      0.005      7.580      0.000       0.029       0.050
# diff_fta       0.0676      0.008      8.261      0.000       0.052       0.084
# diff_3pa       0.0156      0.008      1.975      0.048       0.000       0.031
# ==============================================================================
#                        Season 2016 - Excluding diff_2p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1316
# Model:                          Logit   Df Residuals:                     1309
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.2839
# Time:                        15:11:32   Log-Likelihood:                -636.35
# converged:                       True   LL-Null:                       -888.67
# Covariance Type:            nonrobust   LLR p-value:                8.379e-106
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2983      0.070      4.292      0.000       0.162       0.435
# diff_orb       0.0342      0.013      2.640      0.008       0.009       0.060
# diff_tov      -0.1376      0.015     -9.036      0.000      -0.167      -0.108
# diff_3p%       0.1024      0.007     15.525      0.000       0.089       0.115
# diff_ft%       0.0357      0.005      7.146      0.000       0.026       0.045
# diff_fta       0.0704      0.008      8.768      0.000       0.055       0.086
# diff_3pa       0.0092      0.008      1.183      0.237      -0.006       0.024
# ==============================================================================
#                        Season 2016 - Excluding diff_ft%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1316
# Model:                          Logit   Df Residuals:                     1309
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7063
# Time:                        15:11:32   Log-Likelihood:                -260.96
# converged:                       True   LL-Null:                       -888.67
# Covariance Type:            nonrobust   LLR p-value:                4.831e-268
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0150      0.114      0.132      0.895      -0.209       0.239
# diff_orb       0.3759      0.032     11.917      0.000       0.314       0.438
# diff_tov      -0.3493      0.030    -11.696      0.000      -0.408      -0.291
# diff_3p%       0.2741      0.018     15.148      0.000       0.239       0.310
# diff_2p%       0.4729      0.032     14.909      0.000       0.411       0.535
# diff_fta       0.1581      0.016     10.067      0.000       0.127       0.189
# diff_3pa       0.0061      0.012      0.503      0.615      -0.018       0.030
# ==============================================================================
#                        Season 2016 - Excluding diff_fta
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1316
# Model:                          Logit   Df Residuals:                     1309
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6812
# Time:                        15:11:32   Log-Likelihood:                -283.32
# converged:                       True   LL-Null:                       -888.67
# Covariance Type:            nonrobust   LLR p-value:                2.294e-258
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2530      0.109      2.331      0.020       0.040       0.466
# diff_orb       0.3972      0.032     12.338      0.000       0.334       0.460
# diff_tov      -0.3694      0.030    -12.133      0.000      -0.429      -0.310
# diff_3p%       0.2675      0.018     14.987      0.000       0.233       0.302
# diff_2p%       0.4569      0.030     15.108      0.000       0.398       0.516
# diff_ft%       0.0801      0.009      8.993      0.000       0.063       0.098
# diff_3pa      -0.0266      0.011     -2.321      0.020      -0.049      -0.004
# ==============================================================================
#                        Season 2016 - Excluding diff_3pa
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1316
# Model:                          Logit   Df Residuals:                     1309
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7901
# Time:                        15:11:32   Log-Likelihood:                -186.49
# converged:                       True   LL-Null:                       -888.67
# Covariance Type:            nonrobust   LLR p-value:                2.759e-300
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0291      0.139     -0.210      0.834      -0.302       0.243
# diff_orb       0.5384      0.046     11.754      0.000       0.449       0.628
# diff_tov      -0.4872      0.043    -11.329      0.000      -0.571      -0.403
# diff_3p%       0.3644      0.027     13.552      0.000       0.312       0.417
# diff_2p%       0.6178      0.046     13.572      0.000       0.529       0.707
# diff_ft%       0.1242      0.013      9.416      0.000       0.098       0.150
# diff_fta       0.2016      0.019     10.366      0.000       0.163       0.240
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.22 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                        Season 2017 - Excluding diff_orb
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1309
# Model:                          Logit   Df Residuals:                     1302
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6212
# Time:                        15:11:32   Log-Likelihood:                -336.84
# converged:                       True   LL-Null:                       -889.26
# Covariance Type:            nonrobust   LLR p-value:                1.863e-235
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1369      0.100      1.374      0.170      -0.058       0.332
# diff_tov      -0.2846      0.025    -11.593      0.000      -0.333      -0.236
# diff_3p%       0.2146      0.014     15.820      0.000       0.188       0.241
# diff_2p%       0.2834      0.019     15.255      0.000       0.247       0.320
# diff_ft%       0.0522      0.008      6.581      0.000       0.037       0.068
# diff_fta       0.1279      0.013     10.167      0.000       0.103       0.152
# diff_3pa       0.0115      0.011      1.020      0.308      -0.011       0.034
# ==============================================================================
#                        Season 2017 - Excluding diff_tov
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1309
# Model:                          Logit   Df Residuals:                     1302
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.5982
# Time:                        15:11:32   Log-Likelihood:                -357.32
# converged:                       True   LL-Null:                       -889.26
# Covariance Type:            nonrobust   LLR p-value:                1.363e-226
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0651      0.096      0.679      0.497      -0.123       0.253
# diff_orb       0.2617      0.024     10.746      0.000       0.214       0.309
# diff_3p%       0.2199      0.014     16.154      0.000       0.193       0.247
# diff_2p%       0.3166      0.020     15.904      0.000       0.278       0.356
# diff_ft%       0.0635      0.008      8.160      0.000       0.048       0.079
# diff_fta       0.1253      0.012     10.290      0.000       0.101       0.149
# diff_3pa       0.0148      0.011      1.391      0.164      -0.006       0.036
# ==============================================================================
#                        Season 2017 - Excluding diff_3p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1309
# Model:                          Logit   Df Residuals:                     1302
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.2752
# Time:                        15:11:32   Log-Likelihood:                -644.51
# converged:                       True   LL-Null:                       -889.26
# Covariance Type:            nonrobust   LLR p-value:                1.533e-102
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2589      0.069      3.757      0.000       0.124       0.394
# diff_orb       0.0729      0.014      5.067      0.000       0.045       0.101
# diff_tov      -0.1232      0.015     -8.309      0.000      -0.152      -0.094
# diff_2p%       0.1650      0.010     15.788      0.000       0.145       0.185
# diff_ft%       0.0355      0.005      6.785      0.000       0.025       0.046
# diff_fta       0.0590      0.008      7.332      0.000       0.043       0.075
# diff_3pa       0.0072      0.008      0.921      0.357      -0.008       0.022
# ==============================================================================
#                        Season 2017 - Excluding diff_2p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1309
# Model:                          Logit   Df Residuals:                     1302
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.3143
# Time:                        15:11:32   Log-Likelihood:                -609.75
# converged:                       True   LL-Null:                       -889.26
# Covariance Type:            nonrobust   LLR p-value:                1.605e-117
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1839      0.071      2.584      0.010       0.044       0.323
# diff_orb       0.0342      0.014      2.477      0.013       0.007       0.061
# diff_tov      -0.1496      0.016     -9.602      0.000      -0.180      -0.119
# diff_3p%       0.1261      0.008     16.456      0.000       0.111       0.141
# diff_ft%       0.0255      0.005      4.864      0.000       0.015       0.036
# diff_fta       0.0698      0.008      8.292      0.000       0.053       0.086
# diff_3pa       0.0142      0.008      1.783      0.075      -0.001       0.030
# ==============================================================================
#                        Season 2017 - Excluding diff_ft%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1309
# Model:                          Logit   Df Residuals:                     1302
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7210
# Time:                        15:11:32   Log-Likelihood:                -248.09
# converged:                       True   LL-Null:                       -889.26
# Covariance Type:            nonrobust   LLR p-value:                7.201e-274
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0057      0.116     -0.049      0.961      -0.233       0.222
# diff_orb       0.4014      0.035     11.475      0.000       0.333       0.470
# diff_tov      -0.4543      0.037    -12.308      0.000      -0.527      -0.382
# diff_3p%       0.3284      0.022     14.955      0.000       0.285       0.371
# diff_2p%       0.4588      0.032     14.491      0.000       0.397       0.521
# diff_fta       0.1582      0.016     10.042      0.000       0.127       0.189
# diff_3pa      -0.0003      0.013     -0.020      0.984      -0.026       0.025
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.13 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                        Season 2017 - Excluding diff_fta
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1309
# Model:                          Logit   Df Residuals:                     1302
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6763
# Time:                        15:11:32   Log-Likelihood:                -287.82
# converged:                       True   LL-Null:                       -889.26
# Covariance Type:            nonrobust   LLR p-value:                1.136e-256
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2067      0.108      1.919      0.055      -0.004       0.418
# diff_orb       0.3696      0.031     12.114      0.000       0.310       0.429
# diff_tov      -0.3983      0.032    -12.413      0.000      -0.461      -0.335
# diff_3p%       0.2840      0.018     15.386      0.000       0.248       0.320
# diff_2p%       0.4177      0.027     15.267      0.000       0.364       0.471
# diff_ft%       0.0675      0.009      7.383      0.000       0.050       0.085
# diff_3pa      -0.0146      0.012     -1.223      0.222      -0.038       0.009
# ==============================================================================
#                        Season 2017 - Excluding diff_3pa
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1309
# Model:                          Logit   Df Residuals:                     1302
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7674
# Time:                        15:11:32   Log-Likelihood:                -206.88
# converged:                       True   LL-Null:                       -889.26
# Covariance Type:            nonrobust   LLR p-value:                1.032e-291
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0326      0.129      0.253      0.800      -0.220       0.285
# diff_orb       0.4745      0.041     11.609      0.000       0.394       0.555
# diff_tov      -0.4958      0.042    -11.856      0.000      -0.578      -0.414
# diff_3p%       0.3769      0.027     14.029      0.000       0.324       0.430
# diff_2p%       0.5340      0.038     13.880      0.000       0.459       0.609
# diff_ft%       0.0893      0.011      7.964      0.000       0.067       0.111
# diff_fta       0.1848      0.018     10.005      0.000       0.149       0.221
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.19 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                        Season 2018 - Excluding diff_orb
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1312
# Model:                          Logit   Df Residuals:                     1305
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6440
# Time:                        15:11:32   Log-Likelihood:                -316.62
# converged:                       True   LL-Null:                       -889.50
# Covariance Type:            nonrobust   LLR p-value:                2.636e-244
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3786      0.104      3.656      0.000       0.176       0.582
# diff_tov      -0.3277      0.027    -12.001      0.000      -0.381      -0.274
# diff_3p%       0.2429      0.016     15.646      0.000       0.212       0.273
# diff_2p%       0.3106      0.020     15.368      0.000       0.271       0.350
# diff_ft%       0.0533      0.008      7.022      0.000       0.038       0.068
# diff_fta       0.1477      0.013     10.946      0.000       0.121       0.174
# diff_3pa       0.0211      0.011      1.901      0.057      -0.001       0.043
# ==============================================================================
#                        Season 2018 - Excluding diff_tov
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1312
# Model:                          Logit   Df Residuals:                     1305
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6295
# Time:                        15:11:32   Log-Likelihood:                -329.59
# converged:                       True   LL-Null:                       -889.50
# Covariance Type:            nonrobust   LLR p-value:                1.081e-238
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2346      0.100      2.353      0.019       0.039       0.430
# diff_orb       0.3130      0.027     11.485      0.000       0.260       0.366
# diff_3p%       0.2557      0.016     15.744      0.000       0.224       0.287
# diff_2p%       0.3472      0.022     15.653      0.000       0.304       0.391
# diff_ft%       0.0677      0.008      8.516      0.000       0.052       0.083
# diff_fta       0.1509      0.014     10.857      0.000       0.124       0.178
# diff_3pa       0.0076      0.011      0.695      0.487      -0.014       0.029
# ==============================================================================
#                        Season 2018 - Excluding diff_3p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1312
# Model:                          Logit   Df Residuals:                     1305
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.2972
# Time:                        15:11:32   Log-Likelihood:                -625.18
# converged:                       True   LL-Null:                       -889.50
# Covariance Type:            nonrobust   LLR p-value:                5.679e-111
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2076      0.070      2.971      0.003       0.071       0.344
# diff_orb       0.0824      0.015      5.590      0.000       0.054       0.111
# diff_tov      -0.1421      0.016     -9.129      0.000      -0.173      -0.112
# diff_2p%       0.1661      0.010     15.870      0.000       0.146       0.187
# diff_ft%       0.0351      0.005      7.111      0.000       0.025       0.045
# diff_fta       0.0626      0.008      7.629      0.000       0.047       0.079
# diff_3pa       0.0025      0.007      0.336      0.737      -0.012       0.017
# ==============================================================================
#                        Season 2018 - Excluding diff_2p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1312
# Model:                          Logit   Df Residuals:                     1305
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.2879
# Time:                        15:11:32   Log-Likelihood:                -633.42
# converged:                       True   LL-Null:                       -889.50
# Covariance Type:            nonrobust   LLR p-value:                2.014e-107
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4364      0.070      6.214      0.000       0.299       0.574
# diff_orb       0.0306      0.014      2.253      0.024       0.004       0.057
# diff_tov      -0.1286      0.015     -8.572      0.000      -0.158      -0.099
# diff_3p%       0.1194      0.008     15.759      0.000       0.105       0.134
# diff_ft%       0.0306      0.005      6.035      0.000       0.021       0.041
# diff_fta       0.0806      0.009      9.438      0.000       0.064       0.097
# diff_3pa       0.0179      0.007      2.415      0.016       0.003       0.033
# ==============================================================================
#                        Season 2018 - Excluding diff_ft%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1312
# Model:                          Logit   Df Residuals:                     1305
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7493
# Time:                        15:11:32   Log-Likelihood:                -223.04
# converged:                       True   LL-Null:                       -889.50
# Covariance Type:            nonrobust   LLR p-value:                8.085e-285
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2933      0.123      2.378      0.017       0.052       0.535
# diff_orb       0.4522      0.040     11.438      0.000       0.375       0.530
# diff_tov      -0.4819      0.040    -12.041      0.000      -0.560      -0.403
# diff_3p%       0.3858      0.027     14.234      0.000       0.333       0.439
# diff_2p%       0.5293      0.038     14.031      0.000       0.455       0.603
# diff_fta       0.1698      0.017      9.954      0.000       0.136       0.203
# diff_3pa       0.0338      0.014      2.456      0.014       0.007       0.061
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.16 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                        Season 2018 - Excluding diff_fta
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1312
# Model:                          Logit   Df Residuals:                     1305
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7171
# Time:                        15:11:32   Log-Likelihood:                -251.66
# converged:                       True   LL-Null:                       -889.50
# Covariance Type:            nonrobust   LLR p-value:                1.997e-272
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4016      0.116      3.475      0.001       0.175       0.628
# diff_orb       0.4930      0.041     12.056      0.000       0.413       0.573
# diff_tov      -0.4814      0.039    -12.430      0.000      -0.557      -0.405
# diff_3p%       0.3581      0.025     14.464      0.000       0.310       0.407
# diff_2p%       0.5217      0.036     14.493      0.000       0.451       0.592
# diff_ft%       0.0802      0.010      8.421      0.000       0.062       0.099
# diff_3pa      -0.0069      0.013     -0.524      0.600      -0.032       0.019
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.16 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                        Season 2018 - Excluding diff_3pa
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1312
# Model:                          Logit   Df Residuals:                     1305
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.8100
# Time:                        15:11:32   Log-Likelihood:                -169.02
# converged:                       True   LL-Null:                       -889.50
# Covariance Type:            nonrobust   LLR p-value:                3.273e-308
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2679      0.143      1.872      0.061      -0.013       0.548
# diff_orb       0.5894      0.052     11.266      0.000       0.487       0.692
# diff_tov      -0.5926      0.053    -11.188      0.000      -0.696      -0.489
# diff_3p%       0.4657      0.035     13.203      0.000       0.397       0.535
# diff_2p%       0.6506      0.050     13.005      0.000       0.553       0.749
# diff_ft%       0.1040      0.012      8.559      0.000       0.080       0.128
# diff_fta       0.2031      0.021      9.606      0.000       0.162       0.245
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.26 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                        Season 2019 - Excluding diff_orb
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1311
# Model:                          Logit   Df Residuals:                     1304
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6001
# Time:                        15:11:32   Log-Likelihood:                -354.77
# converged:                       True   LL-Null:                       -887.18
# Covariance Type:            nonrobust   LLR p-value:                8.541e-227
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3067      0.097      3.173      0.002       0.117       0.496
# diff_tov      -0.2541      0.022    -11.298      0.000      -0.298      -0.210
# diff_3p%       0.2396      0.015     16.133      0.000       0.210       0.269
# diff_2p%       0.2427      0.016     15.036      0.000       0.211       0.274
# diff_ft%       0.0628      0.008      8.347      0.000       0.048       0.078
# diff_fta       0.1284      0.012     10.311      0.000       0.104       0.153
# diff_3pa       0.0172      0.010      1.653      0.098      -0.003       0.038
# ==============================================================================
#                        Season 2019 - Excluding diff_tov
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1311
# Model:                          Logit   Df Residuals:                     1304
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6100
# Time:                        15:11:32   Log-Likelihood:                -346.02
# converged:                       True   LL-Null:                       -887.18
# Covariance Type:            nonrobust   LLR p-value:                1.403e-230
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2412      0.098      2.469      0.014       0.050       0.433
# diff_orb       0.2875      0.025     11.368      0.000       0.238       0.337
# diff_3p%       0.2648      0.016     16.235      0.000       0.233       0.297
# diff_2p%       0.2912      0.019     15.277      0.000       0.254       0.329
# diff_ft%       0.0735      0.008      9.161      0.000       0.058       0.089
# diff_fta       0.1302      0.012     10.447      0.000       0.106       0.155
# diff_3pa       0.0136      0.010      1.364      0.172      -0.006       0.033
# ==============================================================================
#                        Season 2019 - Excluding diff_3p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1311
# Model:                          Logit   Df Residuals:                     1304
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.2467
# Time:                        15:11:32   Log-Likelihood:                -668.34
# converged:                       True   LL-Null:                       -887.18
# Covariance Type:            nonrobust   LLR p-value:                 2.214e-91
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2789      0.067      4.135      0.000       0.147       0.411
# diff_orb       0.0861      0.014      6.208      0.000       0.059       0.113
# diff_tov      -0.1247      0.014     -8.698      0.000      -0.153      -0.097
# diff_2p%       0.1391      0.009     14.964      0.000       0.121       0.157
# diff_ft%       0.0388      0.005      7.702      0.000       0.029       0.049
# diff_fta       0.0561      0.008      7.201      0.000       0.041       0.071
# diff_3pa      -0.0047      0.007     -0.675      0.500      -0.018       0.009
# ==============================================================================
#                        Season 2019 - Excluding diff_2p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1311
# Model:                          Logit   Df Residuals:                     1304
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.3331
# Time:                        15:11:32   Log-Likelihood:                -591.65
# converged:                       True   LL-Null:                       -887.18
# Covariance Type:            nonrobust   LLR p-value:                1.980e-124
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4162      0.073      5.709      0.000       0.273       0.559
# diff_orb       0.0580      0.014      4.274      0.000       0.031       0.085
# diff_tov      -0.1256      0.015     -8.243      0.000      -0.155      -0.096
# diff_3p%       0.1463      0.009     16.692      0.000       0.129       0.163
# diff_ft%       0.0427      0.005      7.891      0.000       0.032       0.053
# diff_fta       0.0756      0.009      8.691      0.000       0.059       0.093
# diff_3pa       0.0088      0.007      1.171      0.241      -0.006       0.023
# ==============================================================================
#                        Season 2019 - Excluding diff_ft%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1311
# Model:                          Logit   Df Residuals:                     1304
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6851
# Time:                        15:11:32   Log-Likelihood:                -279.40
# converged:                       True   LL-Null:                       -887.18
# Covariance Type:            nonrobust   LLR p-value:                2.068e-259
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2703      0.110      2.462      0.014       0.055       0.485
# diff_orb       0.3699      0.031     11.852      0.000       0.309       0.431
# diff_tov      -0.3633      0.030    -12.027      0.000      -0.422      -0.304
# diff_3p%       0.3353      0.022     15.578      0.000       0.293       0.378
# diff_2p%       0.3916      0.026     14.823      0.000       0.340       0.443
# diff_fta       0.1343      0.014      9.636      0.000       0.107       0.162
# diff_3pa      -0.0024      0.012     -0.202      0.840      -0.025       0.021
# ==============================================================================
#                        Season 2019 - Excluding diff_fta
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1311
# Model:                          Logit   Df Residuals:                     1304
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6726
# Time:                        15:11:32   Log-Likelihood:                -290.46
# converged:                       True   LL-Null:                       -887.18
# Covariance Type:            nonrobust   LLR p-value:                1.268e-254
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3377      0.107      3.144      0.002       0.127       0.548
# diff_orb       0.3906      0.031     12.490      0.000       0.329       0.452
# diff_tov      -0.3713      0.030    -12.366      0.000      -0.430      -0.312
# diff_3p%       0.3296      0.021     15.533      0.000       0.288       0.371
# diff_2p%       0.3808      0.025     15.032      0.000       0.331       0.430
# diff_ft%       0.0792      0.009      8.999      0.000       0.062       0.096
# diff_3pa      -0.0209      0.011     -1.885      0.059      -0.043       0.001
# ==============================================================================
#                        Season 2019 - Excluding diff_3pa
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1311
# Model:                          Logit   Df Residuals:                     1304
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7583
# Time:                        15:11:32   Log-Likelihood:                -214.40
# converged:                       True   LL-Null:                       -887.18
# Covariance Type:            nonrobust   LLR p-value:                1.497e-287
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2396      0.126      1.897      0.058      -0.008       0.487
# diff_orb       0.4655      0.039     11.807      0.000       0.388       0.543
# diff_tov      -0.4371      0.037    -11.658      0.000      -0.511      -0.364
# diff_3p%       0.4084      0.028     14.400      0.000       0.353       0.464
# diff_2p%       0.4710      0.034     13.962      0.000       0.405       0.537
# diff_ft%       0.1037      0.011      9.253      0.000       0.082       0.126
# diff_fta       0.1699      0.017     10.035      0.000       0.137       0.203
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.17 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                        Season 2020 - Excluding diff_orb
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1138
# Model:                          Logit   Df Residuals:                     1131
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6151
# Time:                        15:11:32   Log-Likelihood:                -301.67
# converged:                       True   LL-Null:                       -783.67
# Covariance Type:            nonrobust   LLR p-value:                5.454e-205
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1395      0.104      1.343      0.179      -0.064       0.343
# diff_tov      -0.3022      0.028    -10.939      0.000      -0.356      -0.248
# diff_3p%       0.2671      0.018     15.019      0.000       0.232       0.302
# diff_2p%       0.2705      0.019     14.211      0.000       0.233       0.308
# diff_ft%       0.0565      0.008      6.775      0.000       0.040       0.073
# diff_fta       0.1354      0.013     10.227      0.000       0.109       0.161
# diff_3pa       0.0043      0.011      0.379      0.704      -0.018       0.027
# ==============================================================================
#                        Season 2020 - Excluding diff_tov
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1138
# Model:                          Logit   Df Residuals:                     1131
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6017
# Time:                        15:11:32   Log-Likelihood:                -312.11
# converged:                       True   LL-Null:                       -783.67
# ...
# Model:                          Logit   Df Residuals:                     1313
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6975
# Time:                        15:11:33   Log-Likelihood:                -271.54
# converged:                       True   LL-Null:                       -897.53
# Covariance Type:            nonrobust   LLR p-value:                2.686e-267
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2605      0.110      2.364      0.018       0.045       0.476
# diff_orb       0.4446      0.035     12.871      0.000       0.377       0.512
# diff_tov      -0.4422      0.035    -12.490      0.000      -0.512      -0.373
# diff_3p%       0.4047      0.027     15.108      0.000       0.352       0.457
# diff_2p%       0.4198      0.028     14.972      0.000       0.365       0.475
# diff_ft%       0.0984      0.010      9.984      0.000       0.079       0.118
# diff_3pa      -0.0283      0.011     -2.651      0.008      -0.049      -0.007
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.12 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                        Season 2023 - Excluding diff_3pa
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1320
# Model:                          Logit   Df Residuals:                     1313
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7853
# Time:                        15:11:33   Log-Likelihood:                -192.74
# converged:                       True   LL-Null:                       -897.53
# Covariance Type:            nonrobust   LLR p-value:                2.041e-301
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0746      0.132      0.566      0.571      -0.184       0.333
# diff_orb       0.5567      0.047     11.870      0.000       0.465       0.649
# diff_tov      -0.5868      0.050    -11.822      0.000      -0.684      -0.489
# diff_3p%       0.5333      0.039     13.532      0.000       0.456       0.611
# diff_2p%       0.5514      0.041     13.422      0.000       0.471       0.632
# diff_ft%       0.1201      0.012      9.619      0.000       0.096       0.145
# diff_fta       0.2009      0.020      9.953      0.000       0.161       0.240
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.23 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                        Season 2024 - Excluding diff_orb
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1308
# Model:                          Logit   Df Residuals:                     1301
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6520
# Time:                        15:11:33   Log-Likelihood:                -313.47
# converged:                       True   LL-Null:                       -900.75
# Covariance Type:            nonrobust   LLR p-value:                1.537e-250
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2307      0.105      2.198      0.028       0.025       0.436
# diff_tov      -0.2757      0.025    -10.844      0.000      -0.325      -0.226
# diff_3p%       0.2701      0.017     15.727      0.000       0.236       0.304
# diff_2p%       0.2685      0.018     15.113      0.000       0.234       0.303
# diff_ft%       0.0486      0.007      6.562      0.000       0.034       0.063
# diff_fta       0.1340      0.014      9.718      0.000       0.107       0.161
# diff_3pa       0.0060      0.012      0.517      0.605      -0.017       0.029
# ==============================================================================
#                        Season 2024 - Excluding diff_tov
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1308
# Model:                          Logit   Df Residuals:                     1301
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6548
# Time:                        15:11:33   Log-Likelihood:                -310.96
# converged:                       True   LL-Null:                       -900.75
# Covariance Type:            nonrobust   LLR p-value:                1.260e-251
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0777      0.104      0.749      0.454      -0.126       0.281
# diff_orb       0.2863      0.026     11.033      0.000       0.235       0.337
# diff_3p%       0.2958      0.019     15.933      0.000       0.259       0.332
# diff_2p%       0.3112      0.020     15.530      0.000       0.272       0.350
# diff_ft%       0.0578      0.008      7.219      0.000       0.042       0.074
# diff_fta       0.1412      0.014     10.040      0.000       0.114       0.169
# diff_3pa      -0.0018      0.012     -0.152      0.879      -0.025       0.021
# ==============================================================================
#                        Season 2024 - Excluding diff_3p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1308
# Model:                          Logit   Df Residuals:                     1301
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.2865
# Time:                        15:11:33   Log-Likelihood:                -642.72
# converged:                       True   LL-Null:                       -900.75
# Covariance Type:            nonrobust   LLR p-value:                2.905e-108
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0853      0.069      1.228      0.219      -0.051       0.221
# diff_orb       0.0653      0.014      4.835      0.000       0.039       0.092
# diff_tov      -0.1240      0.015     -8.311      0.000      -0.153      -0.095
# diff_2p%       0.1466      0.009     16.238      0.000       0.129       0.164
# diff_ft%       0.0261      0.005      5.369      0.000       0.017       0.036
# diff_fta       0.0570      0.008      6.840      0.000       0.041       0.073
# diff_3pa      -0.0008      0.008     -0.097      0.923      -0.016       0.015
# ==============================================================================
#                        Season 2024 - Excluding diff_2p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1308
# Model:                          Logit   Df Residuals:                     1301
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.3277
# Time:                        15:11:33   Log-Likelihood:                -605.59
# converged:                       True   LL-Null:                       -900.75
# Covariance Type:            nonrobust   LLR p-value:                2.856e-124
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1540      0.072      2.151      0.031       0.014       0.294
# diff_orb       0.0487      0.014      3.580      0.000       0.022       0.075
# diff_tov      -0.1391      0.015     -9.003      0.000      -0.169      -0.109
# diff_3p%       0.1559      0.009     16.685      0.000       0.138       0.174
# diff_ft%       0.0297      0.005      5.835      0.000       0.020       0.040
# diff_fta       0.0749      0.009      8.325      0.000       0.057       0.093
# diff_3pa      -0.0083      0.008     -0.999      0.318      -0.024       0.008
# ==============================================================================
#                        Season 2024 - Excluding diff_ft%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1308
# Model:                          Logit   Df Residuals:                     1301
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7533
# Time:                        15:11:33   Log-Likelihood:                -222.22
# converged:                       True   LL-Null:                       -900.75
# Covariance Type:            nonrobust   LLR p-value:                4.790e-290
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2735      0.125      2.190      0.029       0.029       0.518
# diff_orb       0.3962      0.035     11.326      0.000       0.328       0.465
# diff_tov      -0.4118      0.037    -11.266      0.000      -0.483      -0.340
# diff_3p%       0.4076      0.028     14.715      0.000       0.353       0.462
# diff_2p%       0.4210      0.029     14.387      0.000       0.364       0.478
# diff_fta       0.1582      0.017      9.203      0.000       0.125       0.192
# diff_3pa      -0.0272      0.014     -1.911      0.056      -0.055       0.001
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.15 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                        Season 2024 - Excluding diff_fta
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1308
# Model:                          Logit   Df Residuals:                     1301
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7315
# Time:                        15:11:33   Log-Likelihood:                -241.82
# converged:                       True   LL-Null:                       -900.75
# Covariance Type:            nonrobust   LLR p-value:                1.480e-281
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3188      0.119      2.674      0.007       0.085       0.552
# diff_orb       0.4211      0.035     11.942      0.000       0.352       0.490
# diff_tov      -0.4349      0.037    -11.829      0.000      -0.507      -0.363
# diff_3p%       0.4072      0.028     14.536      0.000       0.352       0.462
# diff_2p%       0.4278      0.030     14.360      0.000       0.369       0.486
# diff_ft%       0.0813      0.010      8.201      0.000       0.062       0.101
# diff_3pa      -0.0619      0.013     -4.668      0.000      -0.088      -0.036
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.16 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                        Season 2024 - Excluding diff_3pa
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                 1308
# Model:                          Logit   Df Residuals:                     1301
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.8047
# Time:                        15:11:33   Log-Likelihood:                -175.89
# converged:                       True   LL-Null:                       -900.75
# Covariance Type:            nonrobust   LLR p-value:                4.155e-310
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2557      0.141      1.814      0.070      -0.021       0.532
# diff_orb       0.5138      0.047     10.983      0.000       0.422       0.605
# diff_tov      -0.5125      0.047    -10.926      0.000      -0.604      -0.421
# diff_3p%       0.5001      0.038     13.149      0.000       0.426       0.575
# diff_2p%       0.5191      0.040     13.054      0.000       0.441       0.597
# diff_ft%       0.1022      0.013      8.166      0.000       0.078       0.127
# diff_fta       0.1916      0.020      9.538      0.000       0.152       0.231
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.24 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#               2016      2017      2018      2019      2020      2021  \
# diff_orb  0.616040  0.621218  0.644042  0.600115  0.615056  0.648149
# diff_tov  0.631350  0.598181  0.629461  0.609974  0.601726  0.624501
# diff_3p%  0.312739  0.275231  0.297155  0.246663  0.235621  0.228887
# diff_2p%  0.283934  0.314317  0.287895  0.333112  0.311429  0.348123
# diff_ft%  0.706347  0.721016  0.749255  0.685065  0.711869  0.722900
# diff_fta  0.681193  0.676341  0.717077  0.672598  0.673401  0.704962
# diff_3pa  0.790143  0.767360  0.809986  0.758329  0.775648  0.776864
#
#               2022      2023      2024
# diff_orb  0.645540  0.595589  0.651987
# diff_tov  0.651418  0.587411  0.654774
# diff_3p%  0.249765  0.216815  0.286465
# diff_2p%  0.366440  0.314801  0.327682
# diff_ft%  0.751140  0.703316  0.753298
# diff_fta  0.737089  0.697459  0.731530
# diff_3pa  0.817206  0.785255  0.804728

# %%
import pandas as pd
import statsmodels.api as sm

# The factors we want to test
factors = ['diff_orb', 'diff_tov', 'diff_3p%', 'diff_2p%', 'diff_ft%', 'diff_fta', 'diff_3pa']

# Read in the cleansed data
df = pd.read_csv('/Users/moneysniper/Documents/NBA_analysis_project/gamelogs/nba_games_cleansed.csv')

# Filter down to home games and drop rows missing the columns of interest
cols_to_select = [
    'home', 'season', 'won', 'diff_pts', 'diff_orb', 'diff_tov', 
    'diff_3p%', 'diff_2p%', 'diff_ft%', 'diff_fta', 'diff_3pa'
]
df = (
    df[df["home"] == 1]
    .reset_index(drop=True)[cols_to_select]
    .dropna(subset=cols_to_select)
)

# Group the cleansed data by season
grouped = df.groupby('season')

# Dictionary to store the differences in pseudo-R^2
pseudo_r_squared_diff = {}

for season_name, group in grouped:
    # Drop any remaining missing values for these columns
    group = group.dropna(subset=factors + ['won'])
    
    # 1) Fit the "full" model with all factors
    X_full = sm.add_constant(group[factors])
    y = group['won']
    full_model = sm.Logit(y, X_full).fit(disp=0)
    full_model_pr2 = full_model.prsquared
    
    # Prepare to store differences for this season
    pseudo_r_squared_diff[season_name] = {}
    
    # 2) For each factor, remove it and fit the "reduced" model
    for excluded_factor in factors:
        # Subset of factors that excludes the current factor
        reduced_factors = [f for f in factors if f != excluded_factor]
        
        X_reduced = sm.add_constant(group[reduced_factors])
        reduced_model = sm.Logit(y, X_reduced).fit(disp=0)
        reduced_model_pr2 = reduced_model.prsquared
        
        # 3) Difference in pseudo-R^2: full minus reduced
        pr2_diff = full_model_pr2 - reduced_model_pr2
        pseudo_r_squared_diff[season_name][excluded_factor] = pr2_diff

# Convert the dictionary of differences to a DataFrame
pseudo_r_squared_diff_df = pd.DataFrame(pseudo_r_squared_diff)

# Optionally, save to CSV
pseudo_r_squared_diff_df.to_csv('pseudo_r_squared_diff.csv', index=True)

# Print or inspect the results
print(pseudo_r_squared_diff_df)
# Out:
#               2016      2017      2018      2019      2020      2021  \
# diff_orb  0.175430  0.146205  0.167032  0.158220  0.160648  0.128738
# diff_tov  0.160119  0.169243  0.181612  0.148361  0.173978  0.152386
# diff_3p%  0.478730  0.492192  0.513918  0.511672  0.540083  0.548000
# diff_2p%  0.507536  0.453106  0.523178  0.425223  0.464275  0.428764
# diff_ft%  0.085123  0.046407  0.061818  0.073270  0.063835  0.053987
# diff_fta  0.110276  0.091083  0.093997  0.085737  0.102303  0.071925
# diff_3pa  0.001327  0.000064  0.001087  0.000006  0.000057  0.000022
#
#               2022      2023      2024
# diff_orb  0.171716  0.189833  0.154112
# diff_tov  0.165838  0.198012  0.151326
# diff_3p%  0.567491  0.568607  0.519635
# diff_2p%  0.450816  0.470622  0.478417
# diff_ft%  0.066116  0.082106  0.052802
# diff_fta  0.080166  0.087963  0.074570
# diff_3pa  0.000050  0.000167  0.001372

# %%
import pandas as pd
import statsmodels.api as sm

# The factors we want to test
factors = ['diff_orb', 'diff_tov', 'diff_3p%', 'diff_2p%', 'diff_ft%', 'diff_fta', 'diff_3pa']

# Read in the cleansed data
df = pd.read_csv('/Users/moneysniper/Documents/NBA_analysis_project/gamelogs/nba_games_cleansed.csv')

# Filter down to home games and drop rows missing the columns of interest
cols_to_select = [
    'home', 'season', 'won', 'diff_pts', 'diff_orb', 'diff_tov', 
    'diff_3p%', 'diff_2p%', 'diff_ft%', 'diff_fta', 'diff_3pa'
]
df = (
    df[df["home"] == 1]                  # Keep only home games
    .reset_index(drop=True)[cols_to_select]
    .dropna(subset=cols_to_select)       # Drop rows with NaNs in the relevant columns
)

# Drop any remaining missing values for the factors + 'won'
df = df.dropna(subset=factors + ['won'])

# Dictionary to store the pseudo-R^2 of each “excluded-factor” model
pseudo_r_squared = {}

# Fit a logistic regression model for each factor excluded
for excluded_factor in factors:
    # Create a list of factors that excludes the current factor
    factors_subset = [f for f in factors if f != excluded_factor]

    X = df[factors_subset]
    y = df['won']
    
    # Add a constant term for the logistic model
    X = sm.add_constant(X)
    
    # Fit the logistic regression
    model = sm.Logit(y, X)
    result = model.fit(disp=0)
    
    # Print summary (optional)
    print(result.summary(title=f'Excluding {excluded_factor}'))
    
    # Store the pseudo R-squared for this model
    pseudo_r_squared[excluded_factor] = result.prsquared

# Convert the dictionary of results to a DataFrame
pseudo_r_squared_df = pd.DataFrame.from_dict(pseudo_r_squared, orient='index', columns=['Pseudo_R2_Excluded'])
pseudo_r_squared_df.to_csv('pseudo_r_squared_cleansed_total.csv', index=True)

print(pseudo_r_squared_df)
# Out:
#                               Excluding diff_orb
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                11508
# Model:                          Logit   Df Residuals:                    11501
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6163
# Time:                        15:42:48   Log-Likelihood:                -3017.0
# converged:                       True   LL-Null:                       -7863.5
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1842      0.033      5.596      0.000       0.120       0.249
# diff_tov      -0.2815      0.008    -34.301      0.000      -0.298      -0.265
# diff_3p%       0.2388      0.005     47.597      0.000       0.229       0.249
# diff_2p%       0.2643      0.006     45.587      0.000       0.253       0.276
# diff_ft%       0.0572      0.003     22.559      0.000       0.052       0.062
# diff_fta       0.1351      0.004     30.905      0.000       0.127       0.144
# diff_3pa       0.0110      0.004      2.996      0.003       0.004       0.018
# ==============================================================================
#                               Excluding diff_tov
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                11508
# Model:                          Logit   Df Residuals:                    11501
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6111
# Time:                        15:42:48   Log-Likelihood:                -3058.3
# converged:                       True   LL-Null:                       -7863.5
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1190      0.033      3.643      0.000       0.055       0.183
# diff_orb       0.2792      0.008     33.611      0.000       0.263       0.296
# diff_3p%       0.2510      0.005     48.365      0.000       0.241       0.261
# diff_2p%       0.3003      0.006     46.783      0.000       0.288       0.313
# diff_ft%       0.0669      0.003     25.657      0.000       0.062       0.072
# diff_fta       0.1324      0.004     30.644      0.000       0.124       0.141
# diff_3pa       0.0117      0.004      3.278      0.001       0.005       0.019
# ==============================================================================
#                               Excluding diff_3p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                11508
# Model:                          Logit   Df Residuals:                    11501
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.2568
# Time:                        15:42:49   Log-Likelihood:                -5844.2
# converged:                       True   LL-Null:                       -7863.5
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1869      0.023      8.223      0.000       0.142       0.231
# diff_orb       0.0720      0.005     15.628      0.000       0.063       0.081
# diff_tov      -0.1196      0.005    -24.514      0.000      -0.129      -0.110
# diff_2p%       0.1448      0.003     45.858      0.000       0.139       0.151
# diff_ft%       0.0353      0.002     21.106      0.000       0.032       0.039
# diff_fta       0.0554      0.003     20.597      0.000       0.050       0.061
# diff_3pa       0.0024      0.002      0.972      0.331      -0.002       0.007
# ==============================================================================
#                               Excluding diff_2p%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                11508
# Model:                          Logit   Df Residuals:                    11501
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.3130
# Time:                        15:42:49   Log-Likelihood:                -5402.3
# converged:                       True   LL-Null:                       -7863.5
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2459      0.024     10.323      0.000       0.199       0.293
# diff_orb       0.0487      0.005     10.592      0.000       0.040       0.058
# diff_tov      -0.1327      0.005    -25.884      0.000      -0.143      -0.123
# diff_3p%       0.1368      0.003     48.872      0.000       0.131       0.142
# diff_ft%       0.0338      0.002     19.290      0.000       0.030       0.037
# diff_fta       0.0729      0.003     25.011      0.000       0.067       0.079
# diff_3pa       0.0014      0.003      0.531      0.595      -0.004       0.006
# ==============================================================================
#                               Excluding diff_ft%
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                11508
# Model:                          Logit   Df Residuals:                    11501
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7064
# Time:                        15:42:49   Log-Likelihood:                -2308.9
# converged:                       True   LL-Null:                       -7863.5
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0891      0.038      2.351      0.019       0.015       0.163
# diff_orb       0.3716      0.011     34.627      0.000       0.351       0.393
# diff_tov      -0.3955      0.011    -35.802      0.000      -0.417      -0.374
# diff_3p%       0.3434      0.008     45.672      0.000       0.329       0.358
# diff_2p%       0.4087      0.009     44.218      0.000       0.391       0.427
# diff_fta       0.1531      0.005     29.552      0.000       0.143       0.163
# diff_3pa      -0.0005      0.004     -0.109      0.913      -0.009       0.008
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.10 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#                               Excluding diff_fta
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                11508
# Model:                          Logit   Df Residuals:                    11501
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.6819
# Time:                        15:42:49   Log-Likelihood:                -2501.4
# converged:                       True   LL-Null:                       -7863.5
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2107      0.036      5.826      0.000       0.140       0.282
# diff_orb       0.3901      0.011     36.398      0.000       0.369       0.411
# diff_tov      -0.3874      0.011    -36.560      0.000      -0.408      -0.367
# diff_3p%       0.3271      0.007     45.492      0.000       0.313       0.341
# diff_2p%       0.3983      0.009     44.898      0.000       0.381       0.416
# diff_ft%       0.0783      0.003     25.931      0.000       0.072       0.084
# diff_3pa      -0.0309      0.004     -7.865      0.000      -0.039      -0.023
# ==============================================================================
#                               Excluding diff_3pa
# ==============================================================================
# Dep. Variable:                    won   No. Observations:                11508
# Model:                          Logit   Df Residuals:                    11501
# Method:                           MLE   Df Model:                            6
# Date:                Thu, 06 Mar 2025   Pseudo R-squ.:                  0.7700
# Time:                        15:42:50   Log-Likelihood:                -1808.3
# converged:                       True   LL-Null:                       -7863.5
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0677      0.043      1.572      0.116      -0.017       0.152
# diff_orb       0.4777      0.014     34.404      0.000       0.450       0.505
# diff_tov      -0.4767      0.014    -34.616      0.000      -0.504      -0.450
# diff_3p%       0.4167      0.010     41.975      0.000       0.397       0.436
# diff_2p%       0.5019      0.012     41.115      0.000       0.478       0.526
# diff_ft%       0.1004      0.004     26.321      0.000       0.093       0.108
# diff_fta       0.1819      0.006     29.920      0.000       0.170       0.194
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.18 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
#           Pseudo_R2_Excluded
# diff_orb            0.616322
# diff_tov            0.611071
# diff_3p%            0.256785
# diff_2p%            0.312994
# diff_ft%            0.706376
# diff_fta            0.681898
# diff_3pa            0.770042

# %%
import pandas as pd
import statsmodels.api as sm

factors = ['diff_orb', 'diff_tov', 'diff_3p%', 'diff_2p%', 'diff_ft%', 'diff_fta', 'diff_3pa']
df = pd.read_csv('/Users/moneysniper/Documents/NBA_analysis_project/gamelogs/nba_games_cleansed.csv')

cols_to_select = [
    'home', 'season', 'won', 'diff_pts', 'diff_orb', 'diff_tov', 
    'diff_3p%', 'diff_2p%', 'diff_ft%', 'diff_fta', 'diff_3pa'
]
df = (
    df[df["home"] == 1]                  
    .reset_index(drop=True)[cols_to_select]
    .dropna(subset=cols_to_select)
)

df = df.dropna(subset=factors + ['won'])

# --- 1) Fit the FULL model with all factors
X_full = df[factors]
y = df['won']
X_full = sm.add_constant(X_full)

full_model = sm.Logit(y, X_full).fit(disp=0)
full_pr2 = full_model.prsquared

# --- 2) Compare each "excluded factor" model
pseudo_r2_dict = {}

for excluded_factor in factors:
    factors_subset = [f for f in factors if f != excluded_factor]
    
    X_reduced = sm.add_constant(df[factors_subset])
    reduced_model = sm.Logit(y, X_reduced).fit(disp=0)
    reduced_pr2 = reduced_model.prsquared
    
    pr2_diff = full_pr2 - reduced_pr2  # how much pseudo-R^2 drops
    
    pseudo_r2_dict[excluded_factor] = {
        'Full_Pseudo_R2': full_pr2,
        'Reduced_Pseudo_R2': reduced_pr2,
        'Delta_Pseudo_R2': pr2_diff
    }

pseudo_r2_df = pd.DataFrame.from_dict(pseudo_r2_dict, orient='index')
pseudo_r2_df.to_csv('pseudo_r_squared_diff_total.csv')
print(pseudo_r2_df)
# Out:
#           Full_Pseudo_R2  Reduced_Pseudo_R2  Delta_Pseudo_R2
# diff_orb        0.770066           0.616322         0.153744
# diff_tov        0.770066           0.611071         0.158995
# diff_3p%        0.770066           0.256785         0.513281
# diff_2p%        0.770066           0.312994         0.457072
# diff_ft%        0.770066           0.706376         0.063690
# diff_fta        0.770066           0.681898         0.088168
# diff_3pa        0.770066           0.770042         0.000024
